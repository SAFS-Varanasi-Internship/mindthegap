# %%
# Quick Start

# %%
# Install mindthegap from GitHub.
# For local development from a clone, replace the line below with:
#   %pip install -e ../..
# %pip install -qU "git+https://github.com/SAFS-Varanasi-Internship/mindthegap.git"

# %load_ext autoreload
# %autoreload 2
